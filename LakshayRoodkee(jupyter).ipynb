# %%
# !pip install opendatasets
# Out:
# ...
#   Obtaining dependency information for opendatasets from https://files.pythonhosted.org/packages/00/e7/12300c2f886b846375c78a4f32c0ae1cd20bdcf305b5ac45b8d7eceda3ec/opendatasets-0.1.22-py3-none-any.whl.metadata
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.6/84.6 kB 652.2 kB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for kaggle: filename=kaggle-1.6.6-py3-none-any.whl size=111945 sha256=7a022c39a8f65e3b5184d111dc58be3f34a4a8014e3680948801337b09864bd7
#   Stored in directory: /Users/lakshay/Library/Caches/pip/wheels/97/06/54/3d44857e6aa73d66d0174f29389e7ea70c007105797e6ec05c
# Successfully built kaggle
# ...

# %%
import opendatasets as od

# %%
dataset = 'https://www.kaggle.com/datasets/willianoliveiragibin/drug-overdose-death/code'

# %%
od.download(dataset)
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: lakshayroodkee
# Your Kaggle Key: ········
# ...
# 100%|███████████████████████████████████████████| 582/582 [00:00<00:00, 338kB/s]

# %%
import os

# %%
data_dir = './drug-overdose-death'

# %%
os.listdir(data_dir)
# Out:
# ['drug-overdose-death-rates new.csv']

# %%
import pandas as pd

# %%
drug_df = pd.read_csv('drug-overdose-death-rates new.csv')
drug_df
# Out:
#            Entity Code  Year  Any opioid death rates (CDC WONDER)  \
# 0   United States  USA  1999                                  2.9
# 1   United States  USA  2000                                  3.0
# 2   United States  USA  2001                                  3.3
# 3   United States  USA  2002                                  4.1
# 4   United States  USA  2003                                  4.5
# 5   United States  USA  2004                                  4.7
# 6   United States  USA  2005                                  5.1
# 7   United States  USA  2006                                  5.9
# 8   United States  USA  2007                                  6.1
# 9   United States  USA  2008                                  6.4
# 10  United States  USA  2009                                  6.6
# 11  United States  USA  2010                                  6.8
# 12  United States  USA  2011                                  7.3
# ...
